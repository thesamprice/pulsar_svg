# %%
filename = './ascii/PSRJ0007+7303_2PC_data.asc'


data = ReadASC(filename)
import scipy

import matplotlib.pyplot as plt
import numpy as np
print data['BEST_FIT_LC']['data'][3]
#plt.plot(data['BEST_FIT_LC']['data'][3])


#plt.show()
# Out:
# [0.31428, 0.39356, 0.48828, 0.5997, 0.72867, 0.87554, 1.03999, 1.22091, 1.41634, 1.6234, 1.83829, 2.05641, 2.27243, 2.48056, 2.67473, 2.84896, 2.99763, 3.11583, 3.19961, 3.24629, 3.25749, 3.25089, 3.22998, 3.19555, 3.14868, 3.09072, 3.02333, 2.94851, 2.86873, 2.78698, 2.70695, 2.63292, 2.56947, 2.52087, 2.48997, 2.47707, 2.47915, 2.48996, 2.50125, 2.50509, 2.49636, 2.47453, 2.44394, 2.41245, 2.38907, 2.38144, 2.39422, 2.4286, 2.48283, 2.55333, 2.63577, 2.7259, 2.8199, 2.91456, 3.00713, 3.09528, 3.17694, 3.25027, 3.31364, 3.3656, 3.40494, 3.43065, 3.442, 3.43704, 3.39831, 3.32171, 3.20962, 3.06562, 2.89429, 2.70098, 2.49145, 2.27164, 2.04734, 1.82399, 1.6064, 1.39867, 1.20407, 1.02498, 0.86295, 0.71872, 0.59235, 0.48332, 0.39063, 0.31299, 0.24888, 0.19668, 0.15476, 0.12157, 0.09563, 0.07564, 0.06043, 0.04901, 0.04056, 0.03437, 0.0299, 0.02672, 0.02448, 0.02293, 0.02186, 0.02114, 0.02065, 0.02033, 0.02012, 0.01999, 0.0199, 0.01985, 0.01982, 0.0198, 0.01978, 0.01978, 0.01977, 0.01977, 0
# ...

# %%
def ReadASC(filename):

    fid = open(filename)
    data = fid.read()
    fid.close()

    import re
    regex = 'EXTNAME\s*=\s*(\w+)'
    import numpy
    groups = []
    for a in re.finditer(regex,data):
        name = a.group(1)
        p_data ={ 'start':a.span()[0]}
        groups.append(p_data)
    
    for i in range(len(groups)-1):
        groups[i]['end'] = groups[i+1]['start']
        
    groups[-1]['end'] = len(data)
    all_data = {}
    for a in groups:
        s = data[a['start']:a['end']]
        
        regex = '\s*([a-zA-Z0-9_]+)\s*=\s*([a-zA-Z0-9_]+)'
        for pair in re.finditer(regex,s):
            d = pair.groups()
            a[d[0]] = d[1]
            
        start = re.search('\n\s+1\s+',s).span()[0]
        s = s[start:].strip()
        a['data'] = []
        a['NCOLS'] = int(a['NCOLS'])
        a['NROWS'] = int(a['NROWS'])
        array = numpy.zeros((a['NCOLS']+1,a['NROWS']))
        #array = numpy.zeros((a['NROWS'],a['NCOLS']))    
    
        #print array
        #print s
        row_count=0    
        for line in s.splitlines():
            
            d = []
            col_count = 0
            for col in line.split():
                #print row_count,col_count
                #array[row_count][col_count] = float(col)
                array[col_count][row_count] = float(col)
                
                col_count += 1
            row_count +=1
            #print array
                
        a['data'] = array.tolist()
        all_data[a['EXTNAME'] ]= a
    
    return all_data
def ReadD3(filename):
    import numpy as np
    data = ReadASC(filename)
    parts = range(len(data['BEST_FIT_LC']['data'][0]));
    p_data = data['BEST_FIT_LC']['data'][3]
    max_ind = np.argmax(p_data)
    #max_val = np.max(p_data)
    p_data = np.roll(p_data,-max_ind + len(p_data)/4)
    
    result = []
    for ind in parts:
        phase = data['BEST_FIT_LC']['data'][1][ind] #Phase start, to #Phase end is row 2
        mag   = data['BEST_FIT_LC']['data'][3][ind]
        mag = p_data[ind]
        row = {'phase':phase,'mag':mag}
        result.append(row)
    return result
        
#ReadD3('/Users/sprice/src/pulsar_poster/2PC_auxiliary_files_v04/PSR_data/ascii/PSRJ0034-0534_2PC_data.asc')

# %%
import os
folder = 'ascii/'
files = os.listdir(folder)
import scipy

import matplotlib.pyplot as plt
import numpy as np
from numpy import cos,sin,pi
count = 10
r_count = 1
#files = ['PSRJ0034-0534_2PC_data.asc']
for filename in files:
    print """kernel.execute("ReadD3('""" +folder + filename  +"""')", {"output": callback}, {silent:false});"""
    continue 
    data = ReadASC(folder + filename)
    p_data = data['BEST_FIT_LC']['data'][3]
    #p_data = p_data + (1-np.min(p_data))
    max_ind = np.argmax(p_data)
    max_val = np.max(p_data)
    length = len(p_data)
    x_pos = np.arange(length)

    x_pos = x_pos*2.0*pi/length
    p_data = np.roll(p_data,-max_ind+r_count)
        
    print filename
    plt.plot(r_count + cos(x_pos)*p_data*count,sin(x_pos)*p_data*count)
    plt.plot(r_count + cos(x_pos), sin(x_pos))
    count +=  0 
    r_count += 10
plt.ylim(-20,60)
plt.xlim(-20,60)
plt.show()
# Out:
# kernel.execute("ReadD3('ascii/PSRJ0007+7303_2PC_data.asc')", {"output": callback}, {silent:false});
# kernel.execute("ReadD3('ascii/PSRJ0023+0923_2PC_data.asc')", {"output": callback}, {silent:false});
# kernel.execute("ReadD3('ascii/PSRJ0030+0451_2PC_data.asc')", {"output": callback}, {silent:false});
# kernel.execute("ReadD3('ascii/PSRJ0034-0534_2PC_data.asc')", {"output": callback}, {silent:false});
# kernel.execute("ReadD3('ascii/PSRJ0101-6422_2PC_data.asc')", {"output": callback}, {silent:false});
# kernel.execute("ReadD3('ascii/PSRJ0102+4839_2PC_data.asc')", {"output": callback}, {silent:false});
# kernel.execute("ReadD3('ascii/PSRJ0106+4855_2PC_data.asc')", {"output": callback}, {silent:false});
# kernel.execute("ReadD3('ascii/PSRJ0205+6449_2PC_data.asc')", {"output": callback}, {silent:false});
# kernel.execute("ReadD3('ascii/PSRJ0218+4232_2PC_data.asc')", {"output": callback}, {silent:false});
# ...

# %%
from IPython.display import HTML
def pyLoadJS(filename):
    fid = open(filename)
    txt = fid.read()
    fid.close()
    return txt
html = """
<body>
<script type="text/javascript" src="http://mbostock.github.com/d3/d3.js"></script>

<svg height="11.5in" width="8in" id="PulsarPlot">
</svg>
"""

javascript = """


<script type="text/Javascript">

function insertAt(array, index) {
    var arrayToInsert = Array.prototype.splice.apply(arguments, [2]);
    return insertArrayAt(array, index, arrayToInsert);
}

function insertArrayAt(array, index, arrayToInsert) {
    Array.prototype.splice.apply(array, [index, 0].concat(arrayToInsert));
    return array;
}

//$.getScript('js/jquery.min.js');
//$.getScript('file:///Users/sprice/src/pulsar_poster/js/d3.v3.min.js');
    function set_value(){
        var var_name = document.getElementById('var_name').value;
        var var_value = document.getElementById('var_value').value;
        var command = var_name + " = '" + var_value + "'";
        console.log("Executing Command: " + command);
        
        var kernel = IPython.notebook.kernel;
        kernel.execute(command);
    }
    
var kernel = IPython.notebook.kernel;

function load_js(out_type,out_data)
{
    out_data = out_data.data["text/plain"];
   $.globalEval(out_data)
   //$.globalEval(d3)
    //eval(out_data);
    //alert(out_data)
}
//kernel.execute("pyLoadJS('js/jquery.min.js')", {"output": load_js}, {silent:false});
kernel.execute("pyLoadJS('js/d3.v3.min.js')",  {"output": load_js}, {silent:false});
function callback(out_type, out_data){

    data = out_data.data["text/plain"];
    eval('var data = ' + data)    
    
scaleX = d3.scale.linear()
        .domain([-4,4])
        .range([0,100])

scaleX2 = d3.scale.linear()
        .domain([0,1])
        .range([25,550])

scaleY = d3.scale.linear()
        .domain([-4,4])
        .range([0,100])
  
scaleY2 = d3.scale.linear()
        .domain([0,4])
        .range([100+y_offset,50+y_offset])
        
    // do_something

    var vis = d3.select("#PulsarPlot")

    vis.selectAll("polygon")
    .data([data])
    .enter().append("polygon")
    .attr("points",function(d) { 
        return d.map(function(d) {
            return [
                    scaleX(Math.cos(d.phase*2*Math.PI)*d.mag),
                    scaleY(Math.sin(d.phase*2*Math.PI)*d.mag)
                    ].join(",");
        }).join(" ");
    })
   .attr("stroke","black")
    .attr("stroke-width",2)
    .attr("fill","none");
    
    console.log(data[0])
    data = [{mag: 0, phase: 0}].concat(data)
    data = data.concat([{mag: 0, phase: 1}])

    var line = d3.svg.line()
    .x(function(d) { return scaleX2(d.phase) })
    .y(function(d) { return scaleY2(d.mag  )})
    .interpolate("basis");
    
    vis.selectAll(".line")
    .data([data])
    .enter().append("path")
    .attr("d", line)    
   .attr("stroke","black")
    .attr("stroke-width",2)
    .attr("fill","white")

y_offset += 8
}
var y_offset = 10

kernel.execute("ReadD3('ascii/PSRJ0007+7303_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0023+0923_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0030+0451_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0034-0534_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0101-6422_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0102+4839_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0106+4855_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0205+6449_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0218+4232_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0248+6021_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0340+4130_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0357+3205_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0437-4715_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0534+2200_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0610-2100_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0613-0200_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0614-3329_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0622+3749_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0631+1036_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0633+0632_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0633+1746_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0659+1414_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0729-1448_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0734-1559_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0742-2822_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0751+1807_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0835-4510_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0908-4913_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ0940-5428_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1016-5857_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1019-5749_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1023-5746_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1024-0719_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1028-5819_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1044-5737_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1048-5832_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1057-5226_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1105-6107_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1119-6127_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1124-3653_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1124-5916_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1125-5825_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1135-6055_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1231-1411_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1357-6429_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1410-6132_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1413-6205_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1418-6058_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1420-6048_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1429-5911_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1446-4701_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1459-6053_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1509-5850_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1513-5908_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1514-4946_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1531-5610_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1600-3053_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1614-2230_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1620-4927_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1648-4611_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1658-5324_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1702-4128_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1709-4429_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1713+0747_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1718-3825_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1730-3350_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1732-3131_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1741+1351_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1741-2054_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1744-1134_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1746-3239_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1747-2958_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1747-4036_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1801-2451_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1803-2149_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1809-2332_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1810+1744_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1813-1246_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1823-3021A_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1826-1256_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1833-1034_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1835-1106_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1836+5925_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1838-0537_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1846+0919_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1858-2216_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1902-5105_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1907+0602_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1939+2134_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1952+3252_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1954+2836_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1957+5033_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1958+2846_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ1959+2048_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2017+0603_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2021+3651_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2021+4026_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2028+3332_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2030+3641_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2030+4415_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2032+4127_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2043+1711_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2043+2740_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2047+1053_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2051-0827_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2055+2539_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2111+4606_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2124-3358_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2139+4716_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2214+3000_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2215+5135_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2229+6114_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2238+5903_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2240+5832_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2241-5236_2PC_data.asc')", {"output": callback}, {silent:false});
kernel.execute("ReadD3('ascii/PSRJ2302+4442_2PC_data.asc')", {"output": callback}, {silent:false});

</script>
</body>
"""
HTML(html + javascript)
# Out:
# <body>
# <script type="text/javascript" src="http://mbostock.github.com/d3/d3.js"></script>
#
# <svg height="11.5in" width="8in" id="PulsarPlot">
# </svg>
#
#
#
# <script type="text/Javascript">
#
# function insertAt(array, index) {
#     var arrayToInsert = Array.prototype.splice.apply(arguments, [2]);
#     return insertArrayAt(array, index, arrayToInsert);
# }
#
# function insertArrayAt(array, index, arrayToInsert) {
#     Array.prototype.splice.apply(array, [index, 0].concat(arrayToInsert));
#     return array;
# }
#
# //$.getScript('js/jquery.min.js');
# //$.getScript('file:///Users/sprice/src/pulsar_poster/js/d3.v3.min.js');
#     function set_value(){
#         var var_name = document.getElementById('var_name').value;
#         var var_value = document.getElementById('var_value').value;
#         var command = var_name + " = '" + var_value + "'";
#         console.log("Executing Command: " + command);
#
#         var kernel = IPython.notebook.kernel;
# ...

# %%
# Out:
# bootstrap.js      bootstrap.min.js  d3.v3.min.js      elements.js       jquery.min.js     jquery.tabs.js    main.js           plugins.js

# %%
# Out:
# HTML	ReadASC	cos	count	data	filename	files	folder	foo
# html	input_form	javascript	length	math	max_ind	max_val	np	os
# p_data	pi	plt	r_count	scipy	sin	x_pos

# %% [markdown]
# <svg height="11in" width="8.5in" id="PulsarPage"></svg>
